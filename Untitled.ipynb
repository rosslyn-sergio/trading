# %%
import pandas as pd
from data import *

# %%
fb_df = read_csv_data("data/fb.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a0c2fc38935> in <module>()
# ----> 1 fb_df = read_csv_data("data/fb.csv")
#
# NameError: name 'read_csv_data' is not defined

# %%
fb_df = pd.read_csv("data/fb.csv")

# %%
fb_df = pd.read_csv("data/fb.csv", index_col="Date", parse_dates=True, na_values=['nan'])

# %%
fb_df.loc['2014-03-18':'2014-03-03',["Adj Close"]]
# Out:
#             Adj Close
# Date
# 2014-03-18  69.190002
# 2014-03-17  68.739998
# 2014-03-14  67.720001
# 2014-03-13  68.830002
# 2014-03-12  70.879997
# 2014-03-11  70.099998
# 2014-03-10  72.029999
# 2014-03-07  69.800003
# 2014-03-06  70.839996
# 2014-03-05  71.570000
# 2014-03-04  68.800003
# 2014-03-03  67.410004

# %%
fb_df["Daily Returns"] = (fb_df["Adj Close"] / fb_df["Adj Close"].shift(1)) - 1

# %%
fb_df.iloc[-3]
# Out:
# Open         5.637000e+01
# High         5.668000e+01
# Low          5.569000e+01
# Close        5.663000e+01
# Volume       4.795180e+07
# Adj Close    5.663000e+01
# Name: 2014-01-23 00:00:00, dtype: float64

# %%
fb_df.at(fb_df.index.values[0])

# %%
norm_fb_df = fb_df/fb_df.iloc[0,:]

# %%
norm_fb_df["Daily Returns"] = (norm_fb_df["Adj Close"] / norm_fb_df["Adj Close"].shift(1)) - 1

# %% [markdown]
# norm_fb_df

# %%
print(norm_fb_df.head(10))
fb_df.head(10)
# Out:
#                 Open      High       Low     Close    Volume  Adj Close  \
# Date
# 2017-01-19  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2017-01-18  1.001404  1.000623  0.995214  1.002901  1.075010   1.002901
# 2017-01-17  0.998518  0.999922  0.999608  1.002509  1.252601   1.002509
# 2017-01-13  0.994229  1.007168  0.999372  1.006194  2.043144   1.006194
# 2017-01-12  0.979568  0.987378  0.979208  0.992709  1.526787   0.992709
# 2017-01-11  0.969742  0.982626  0.973401  0.988553  1.505170   0.988553
# 2017-01-10  0.973407  0.977795  0.975128  0.974912  1.418702   0.974912
# 2017-01-09  0.963503  0.977250  0.965398  0.979224  1.880514   0.979224
# 2017-01-06  0.943461  0.965173  0.941781  0.967542  2.344671   0.967542
# 2017-01-05  0.926928  0.942345  0.928364  0.946060  1.599321   0.946060
#
#             Daily Returns
# Date
# 2017-01-19            NaN
# 2017-01-18       0.002901
# 2017-01-17      -0.000391
# 2017-01-13       0.003676
# ...

# %%
import matplotlib.pyplot as plt

# %%
fb_df.Date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-9c9572c0d7b9> in <module>()
# ----> 1 fb_df.Date
#
# ~/github/VEnvs/tensorflow/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
ax = fb_df.plot(title="Stock price")
ax.set_xlabel("Date")
ax.set_ylabel("Adj Close")
plt.show()

# %%
ax = fb_df.plot(title="Stock price")
bx = fb_df.plot()
bx.set_ylabel("High")
plt.show()

# %%
bx = norm_fb_df["Daily Returns"].plot()
bx.set_ylabel("Daily Returns")
plt.show()
cx = norm_fb_df["Adj Close"].plot()
cx.set_ylabel("Adj Close")
plt.show()

# %%
fb_df['2014-03-06':'2014-03-13']
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Adj Close]
# Index: []

# %%
adj_close = norm_fb_df["Adj Close"]
adj_close_ax = adj_close.plot()
daily_returns = norm_df_fb
plt.show()

# %%
norm_fb_df.head(10)
# Out:
#                 Open      High       Low     Close    Volume  Adj Close  \
# Date
# 2017-01-19  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2017-01-18  1.001404  1.000623  0.995214  1.002901  1.075010   1.002901
# 2017-01-17  0.998518  0.999922  0.999608  1.002509  1.252601   1.002509
# 2017-01-13  0.994229  1.007168  0.999372  1.006194  2.043144   1.006194
# 2017-01-12  0.979568  0.987378  0.979208  0.992709  1.526787   0.992709
# 2017-01-11  0.969742  0.982626  0.973401  0.988553  1.505170   0.988553
# 2017-01-10  0.973407  0.977795  0.975128  0.974912  1.418702   0.974912
# 2017-01-09  0.963503  0.977250  0.965398  0.979224  1.880514   0.979224
# 2017-01-06  0.943461  0.965173  0.941781  0.967542  2.344671   0.967542
# 2017-01-05  0.926928  0.942345  0.928364  0.946060  1.599321   0.946060
#
#             Daily Returns
# Date
# 2017-01-19       0.000000
# 2017-01-18       0.002901
# 2017-01-17      -0.000391
# 2017-01-13       0.003676
# ...

# %%
norm_fb_df.at['2017-01-19',["Daily Returns"]] = 0

# %%
df = norm_fb_df.copy()

# %%
df["Label"] = df["Adj Close"] < df["Adj Close"].shift(-1)

# %%
df["Label"] = df["Label"].astype(int)

# %%
df.head(5)
# Out:
#                 Open      High       Low     Close    Volume  Adj Close  \
# Date
# 2017-01-19  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2017-01-18  1.001404  1.000623  0.995214  1.002901  1.075010   1.002901
# 2017-01-17  0.998518  0.999922  0.999608  1.002509  1.252601   1.002509
# 2017-01-13  0.994229  1.007168  0.999372  1.006194  2.043144   1.006194
# 2017-01-12  0.979568  0.987378  0.979208  0.992709  1.526787   0.992709
#
#             Daily_Returns  Label
# Date
# 2017-01-19       0.000000      1
# 2017-01-18       0.002901      0
# 2017-01-17      -0.000391      1
# 2017-01-13       0.003676      0
# 2017-01-12      -0.013402      0

# %%
df = create_training_set("data/fb.csv")

# %%
from data import *

# %%
df = pd.read_csv("data/fb.csv", index_col="Date", parse_dates=True, na_values=['nan'])
df["Daily_Returns"] = (df["Adj Close"] / df["Adj Close"].shift(1)) - 1
df.at[df.index.values[0], ["Daily_Returns"]] = 0
df.head(5)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2017-01-19  128.229996  128.350006  127.449997  127.550003  12157100
# 2017-01-18  128.410004  128.429993  126.839996  127.919998  13069000
# 2017-01-17  128.039993  128.339996  127.400002  127.870003  15228000
# 2017-01-13  127.489998  129.270004  127.370003  128.339996  24838700
# 2017-01-12  125.610001  126.730003  124.800003  126.620003  18561300
#
#              Adj Close  Daily_Returns
# Date
# 2017-01-19  127.550003       0.000000
# 2017-01-18  127.919998       0.002901
# 2017-01-17  127.870003      -0.000391
# 2017-01-13  128.339996       0.003676
# 2017-01-12  126.620003      -0.013402

# %%
df.at[df.index.values[0],["Daily_Returns"]]=0

# %%
df["Daily_Returns"].at[df.index.values[0], ["Daily_Returns"]] = 0
# Out:
# -------------------------------------------------------
# ValueError            Traceback (most recent call last)
# <ipython-input-10-173d8fb23a54> in <module>()
# ----> 1 df["Daily_Returns"].at[df.index.values[0], ["Daily_Returns"]] = 0
#
# ~/github/VEnvs/tensorflow/lib/python3.5/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    1796             key = self._tuplify(key)
#    1797         if len(key) != self.obj.ndim:
# -> 1798             raise ValueError('Not enough indexers for scalar access '
#    1799                              '(setting)!')
#    1800         key = list(self._convert_key(key, is_setter=True))
#
# ValueError: Not enough indexers for scalar access (setting)!

# %%
filename = "data/fb.csv"
df = pd.read_csv(filename, index_col="Date", parse_dates=True, na_values=['nan'])
df = df/df.iloc[0,:]
df["Daily_Returns"] = (df["Adj Close"] / df["Adj Close"].shift(1)) - 1
df.at[df.index.values[0], ["Daily_Returns"]] = 0
df["Label"] = (df["Adj Close"] < df["Adj Close"].shift(-1)).astype(int)
df.head(10)
# Out:
#                 Open      High       Low     Close    Volume  Adj Close  \
# Date
# 2017-01-19  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2017-01-18  1.001404  1.000623  0.995214  1.002901  1.075010   1.002901
# 2017-01-17  0.998518  0.999922  0.999608  1.002509  1.252601   1.002509
# 2017-01-13  0.994229  1.007168  0.999372  1.006194  2.043144   1.006194
# 2017-01-12  0.979568  0.987378  0.979208  0.992709  1.526787   0.992709
# 2017-01-11  0.969742  0.982626  0.973401  0.988553  1.505170   0.988553
# 2017-01-10  0.973407  0.977795  0.975128  0.974912  1.418702   0.974912
# 2017-01-09  0.963503  0.977250  0.965398  0.979224  1.880514   0.979224
# 2017-01-06  0.943461  0.965173  0.941781  0.967542  2.344671   0.967542
# 2017-01-05  0.926928  0.942345  0.928364  0.946060  1.599321   0.946060
#
#             Daily_Returns  Label
# Date
# 2017-01-19       0.000000      1
# 2017-01-18       0.002901      0
# 2017-01-17      -0.000391      1
# ...

# %%
from data import *
plotModel = PlotModel(title="Log Reg", xlabel="Adj Close", ylabel="Daily Returns")
plot_logistic_regression_data(df,xcol="Adj Close", ycol="Daily_Returns", feature="Label", plotModel=plotModel)

# %%
plotModel = PlotModel(title="Log Reg", xlabel="Adj Close", ylabel="Daily Returns")
plot_logistic_regression_data(df,xcol="High", ycol="Low", feature="Label", plotModel=plotModel)

# %%
plotModel = PlotModel(title="Log Reg", xlabel="Adj Close", ylabel="Daily Returns")
plot_logistic_regression_data(df,xcol="Low", ycol="Daily_Returns", feature="Label", plotModel=plotModel)

# %%
plotModel = PlotModel(title="Log Reg", xlabel="Volume", ylabel="Daily Returns")
plot_logistic_regression_data(df,xcol="Volume", ycol="Daily_Returns", feature="Label", plotModel=plotModel)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close', 'Daily_Returns',
#        'Label'],
#       dtype='object')

# %%
for c in df.columns:
    print(c)
# Out:
# Open
# High
# Low
# Close
# Volume
# Adj Close
# Daily_Returns
# Label

# %%
for c in df.columns[:-1]:
    print(c)
# Out:
# Open
# High
# Low
# Close
# Volume
# Adj Close
# Daily_Returns

# %%
for i in range(len(df.columns)-1):
    for j in range(i+1,len(df.columns)-1):
        x = df.columns[i]
        y = df.columns[j]
        plotModel = PlotModel(title="Log Reg", xlabel=x, ylabel=y)
        plot_logistic_regression_data(df, xcol=x, ycol=y, feature="Label", plotModel=plotModel)

# %%
df.mean()
# Out:
# Open             0.722077
# High             0.728788
# Low              0.718317
# Close            0.725959
# Volume           2.696910
# Adj Close        0.725959
# Daily_Returns   -0.000858
# Label            0.455026
# dtype: float64

# %%
avg = df[["Adj Close","Daily_Returns"]].rolling(center=False,window=5).mean()

# %%
avg.columns = ["A","B"]

# %%
avg.head(10)
# Out:
#                    A         B
# Date
# 2017-01-19       NaN       NaN
# 2017-01-18       NaN       NaN
# 2017-01-17       NaN       NaN
# 2017-01-13       NaN       NaN
# 2017-01-12  1.000862 -0.001443
# 2017-01-11  0.998573 -0.002280
# 2017-01-10  0.992975 -0.005621
# 2017-01-09  0.988318 -0.004658
# 2017-01-06  0.980588 -0.007779
# 2017-01-05  0.971258 -0.009539

# %%
tdf = pd.DataFrame(index=["Date"])
tdf.index = pd.to_datetime(tdf.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/github/VEnvs/tensorflow/lib/python3.5/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas/_libs/tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-c0725b37638c> in <module>()
#       1 tdf = pd.DataFrame(index=["Date"])
# ----> 2 tdf.index = pd.to_datetime(tdf.index)
#
# ...

# %%
tdf
# Out:
# Empty DataFrame
# Columns: []
# Index: [Date]

# %%
pd.concat([tdf,avg],axis=1,join='outer').head(10)
# Out:
#                    A         B
# Date
# 2017-01-19       NaN       NaN
# 2017-01-18       NaN       NaN
# 2017-01-17       NaN       NaN
# 2017-01-13       NaN       NaN
# 2017-01-12  1.000862 -0.001443
# 2017-01-11  0.998573 -0.002280
# 2017-01-10  0.992975 -0.005621
# 2017-01-09  0.988318 -0.004658
# 2017-01-06  0.980588 -0.007779
# 2017-01-05  0.971258 -0.009539

# %%
tdf.index
# Out:
# Index(['Date'], dtype='object')

# %%
avg.index
# Out:
# DatetimeIndex(['2017-01-19', '2017-01-18', '2017-01-17', '2017-01-13',
#                '2017-01-12', '2017-01-11', '2017-01-10', '2017-01-09',
#                '2017-01-06', '2017-01-05',
#                ...
#                '2014-02-03', '2014-01-31', '2014-01-30', '2014-01-29',
#                '2014-01-28', '2014-01-27', '2014-01-24', '2014-01-23',
#                '2014-01-22', '2014-01-21'],
#               dtype='datetime64[ns]', name='Date', length=756, freq=None)

# %%
pd.DatetimeIndex([0])
# Out:
# DatetimeIndex(['1970-01-01'], dtype='datetime64[ns]', freq=None)

# %%
tdf
# Out:
# Empty DataFrame
# Columns: []
# Index: [Date]

# %%
tdf.index = pd.DatetimeIndex([])

# %%
tdf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
tdf.index
# Out:
# DatetimeIndex(['1970-01-01'], dtype='datetime64[ns]', freq=None)

# %%
tdf.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-13cc5b18e8e7> in <module>()
# ----> 1 tdf.clear()
#
# ~/github/VEnvs/tensorflow/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'clear'

# %%
tdf = tdf[1:]

# %%
tdf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
tdf.index
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
fb_df.head(10)
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2017-01-19  128.229996  128.350006  127.449997  127.550003  12157100
# 1  2017-01-18  128.410004  128.429993  126.839996  127.919998  13069000
# 2  2017-01-17  128.039993  128.339996  127.400002  127.870003  15228000
# 3  2017-01-13  127.489998  129.270004  127.370003  128.339996  24838700
# 4  2017-01-12  125.610001  126.730003  124.800003  126.620003  18561300
# 5  2017-01-11  124.349998  126.120003  124.059998  126.089996  18298500
# 6  2017-01-10  124.820000  125.500000  124.279999  124.349998  17247300
# 7  2017-01-09  123.550003  125.430000  123.040001  124.900002  22861600
# 8  2017-01-06  120.980003  123.879997  120.029999  123.410004  28504400
# 9  2017-01-05  118.860001  120.949997  118.320000  120.669998  19443100
#
#     Adj Close
# 0  127.550003
# 1  127.919998
# 2  127.870003
# 3  128.339996
# 4  126.620003
# 5  126.089996
# 6  124.349998
# 7  124.900002
# 8  123.410004
# 9  120.669998

# %%
dict(fb_df.shift(-1).iloc[-1])
# Out:
# {'Adj Close': nan,
#  'Close': nan,
#  'Date': nan,
#  'High': nan,
#  'Label5': nan,
#  'Low': nan,
#  'Open': nan,
#  'Volume': nan}

# %%
int(1 > 0)
# Out:
# 1

# %%
len(fb_df)
# Out:
# 756

# %%
fb_df["Label5"] = [0 for i in range(len(fb_df))]

# %%
fb_df["Label5"].head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Label5, dtype: int64

# %%
fb_
